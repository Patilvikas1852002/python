# %% [markdown]
# ### Python Practice Questions: if, if-else, if-elif-else

# %% [markdown]
# ### Set 1 — 10 Questions on if statement

# %% [raw]
# Set 1 — 10 Questions on if statement \n
# 1 Check if a number is greater than 10. \n
# 2 Check whether a number is positive. \n
# 3 Check if a person is eligible to vote (age ≥ 18). \n
# 4 Check if a number is even.\n
# 5 Check if a student has scored more than 40 marks.\n
# 6 Check if a character entered is a vowel. \n
# 7 Check if a temperature is above 30°C. \n
# 8 Check if a password length is greater than 8 characters. \n
# 9 Check if a number is divisible by 5. \n
# 10 Check if a given year is greater than 2000. \n

# %%
n=10
if n<11:
    print(n,"is greater than n")
# Out:
# 10 is greater than n

# %%
n=10
if n%2==0:
    print(n,"number is  positive")
# Out:
# 10 number is  positive

# %%
n=18
if n>=18:
    print(n,"eligible to vote")
# Out:
# 18 eligible to vote

# %%
n=10
if n%2==0:
    print(n,"number is  even")
# Out:
# 10 number is  even

# %%
n=45
if n>40:
    print(n,"student score more than 40")
# Out:
# 45 student score more than 40

# %%
vowels = ["a", "e", "i", "o", "u"]
char = input("Enter a character: ").lower()  
if len(char) != 1 or not char.isalpha():
    print("Please enter a single alphabet character.")
else:
    if char in vowels:
        print(f"{char} is a vowel.")
    else:
        print(f"{char} is a consonant.")
# Out:
# Enter a character:  A
# a is a vowel.

# %% [raw]
# 7 Check if a temperature is above 30°C. \n
# 8 Check if a password length is greater than 8 characters. \n
# 9 Check if a number is divisible by 5. \n
# 10 Check if a given year is greater than 2000. \n

# %%
temprature=37
if temprature>35:
    print("Temperature is above 32°C")
# Out:
# Temperature is above 32°C

# %%
#Check if a password length is greater than 8 characters
password="vikaspatil"
if len(password)>8:
    print("password length is greater than 8")
# Out:
# password length is greater than 8

# %%
#Check if a number is divisible by 5
year=int(input("enter your number"))
if number%5==0:
    print("divisible by 5")
# Out:
# enter your number 25
# divisible by 5

# %%
#10 Check if a given year is greater than 2000.
year=int(input("enter your year"))

if year>2001:
    print(year,"year is greater than 2001")
# Out:
# enter your year 2002
# 2002 year is greater than 2001

# %% [markdown]
# ### Set 2 — 10 Questions on if–else statement

# %% [raw]
# Set 2 — 10 Questions on if–else statement
# 1 Check whether a number is even or odd.
# 2 Check whether a person is adult or minor.
# 3 Check whether a number is positive or negative.
# 4 Check whether a student has passed or failed (pass ≥ 40).
# 5 Check whether a character is vowel or consonant.
# 6 Check whether a number is divisible by 3 or not.
# 7 Check whether a person can drive (age ≥ 18).
# 8 Check whether a number is zero or non-zero.
# 9 Check whether a student is eligible for scholarship

# %%
#1 Check whether a number is even or odd
evenodd=int(input("enter your number"))
if evenodd%2==0:
            print("entered number is even")
else:
    print("entered number is odd")
# Out:
# enter your number 2
# entered number is even

# %%
#2 Check whether a person is adult or minor.
age=int(input("enter your age"))
if age>=18:
    print(age,"person is adult")
else:
    print(age,"person is minor")
# Out:
# enter your age 18
# 18 person is adult

# %%
#Check whether a number is positive or negative.
num = 5
if num>0:
    print("number is positive")
else:
    print("number is negative")
# Out:
# number is positive

# %%
#4 Check whether a student has passed or failed (pass ≥ 40).
marks=54
if marks>=40:
    print("Passed")
else:
    print("Failed")
# Out:
# Passed

# %%
#5 Check whether a character is vowel or consonant.
vowels = ["a", "e", "i", "o", "u"]
char = input("Enter a character: ").lower()  
if len(char) != 1 or not char.isalpha():
    print("Please enter a single alphabet character.")
else:
    if char in vowels:
        print(f"{char} is a vowel.")
    else:
        print(f"{char} is a consonant.")
# Out:
# Enter a character:  a
# a is a vowel.

# %%
#6 Check whether a number is divisible by 3 or not.
no_1=12
if no_1%3==0:
    print("divisible by 3")
else:
    print("not divisible by 3")
# Out:
# divisible by 3

# %% [raw]
# #7 Check whether a person can drive (age ≥ 18).
# drive=17
# if drive>=18:
#     print("person can drive")
# else:
#     print("person cant drive he/she under-age")

# %%
#8 Check whether a number is zero or non-zero.
zero_nonzero=int(input("enter your number"))
if zero_nonzero==0:
    print("number is zero")
else:
    print("number is non zero")
# Out:
# enter your number 2
# number is non zero

# %%
#9 Check whether a student is eligible for scholarship 
scholership_eligiblity=int(input("enter your marks"))
if scholership_eligiblity>85:
                           print(scholership_eligiblity," eligible for scholership ")
else:
    print(scholership_eligiblity,"not eligible for scholership ")
# Out:
# enter your marks 90
# 90  eligible for scholership

# %% [markdown]
# ### Set 3 — 10 Questions on if–elif–else statement

# %% [raw]
# 1 Classify a number as positive, negative, or zero.
# 2 Grade a student based on marks (A/B/C/Fail).
# 3 Check age category: Minor, Adult, Senior Citizen.
# 4 Traffic light actions: Stop, Wait, Go.
# 5 Classify temperature: Cold, Normal, Hot.
# 6 Determine day type: Weekday or Weekend.
# 7 Classify number as Even, Odd, or Zero.
# 8 Check salary category: Low, Medium, High.
# 9 Check water state: Ice, Liquid, Steam.
# 10 Determine result status: Distinction, First Class, Pass, Fail.

# %%
q1=int(input("enter your number"))
if q1>0:
    print("positive number")
elif q1<0:
    print("Negative number")
else:
    print("it is zero")
# Out:
# enter your number 0
# it is zero

# %%
#2 Grade a student based on marks (A/B/C/Fail).
a_b_c_fail=int(input("enter your marks"))
if a_b_c_fail>=75:
    print("Grade A")
elif a_b_c_fail>=50:
    print("Grade B")
elif a_b_c_fail>=35:
    print("Grade C")
else:
    print("Fail")
# Out:
# enter your marks 34
# Fail

# %%
# 3 Check age category: Minor, Adult, Senior Citizen.
age1=int(input("enter your age"))
if age1>=60:
    print("you are senior citizen")
elif age1>=18:
    print("you are adult")
else:
    print("you are minor")
# Out:
# enter your age 71
# you are senior citizen

# %%
#4 Traffic light actions: Stop, Wait, Go.
traffic_light=input("enter light color")
if traffic_light=="Red":
    print("Stop")
elif traffic_light=="Green":
    print("Go")
elif traffic_light=="Yellow" :
    print("Wait")
# Out:
# enter light color Green
# Go

# %%
#5 Classify temperature: Cold, Normal, Hot.
temp = int(input("Enter temperature: "))
if temp >= 75:
    print("Hot")
elif temp >= 35:
    print("Normal")
else:
    print("Cold")
# Out:
# Enter temperature:  35
# Normal

# %%
#Determine day type: Weekday or Weekend.
day_type = input("Enter your day: ").lower()

if day_type in ["monday", "tuesday", "wednesday", "thursday", "friday"]:
    print("Weekday")
elif day_type in ["saturday", "sunday"]:
    print("Weekend")
else:
    print("Invalid day")
# Out:
# Enter your day:  sunday
# Weekend

# %%
#Determine day type: Weekday or Weekend.
day_type=input("enter your day:")
if day_type=="Monday":
    print("Weekday")
elif day_type=="tuesday":
    print("Weekday")
elif day_type=="wednsday":
    print("Weekday")
elif day_type=="thursday":
    print("Weekday")
elif day_type=="friday":
    print("Weekday")
elif day_type=="saturday" or day_type=="sunday":
    print("weekend")
elif day_type=="sunday":
    print("weekend")
# Out:
# enter your day: sunday
# weekend

# %%
#7 Classify number as Even, Odd, or Zero.
number=int(input("enter a number:"))
if number%2==0:
    print("number is even")
elif number%2!=0:
    print("number is odd")
elif number==0:
    print("number is zero")
# Out:
# enter a number: 44
# number is even

# %%
#8 Check salary category: Low, Medium, High.
salary = int(input("Enter your salary: "))
if salary >= 50000:
    print("High salary")
elif salary >= 20000:
    print("Medium salary")
else:
    print("Low salary")
# Out:
# Enter your salary:  450000
# High salary

# %%
#9 Check water state: Ice, Liquid, Steam.
water_state=input("enter water status")
if water_state=="normal water":
    print("state is liquid")
elif water_state=="solid":
    print("Ice")
else:
    print("steam")
# Out:
# enter water status solid
# Ice

# %%
#10 Determine result status: Distinction, First Class, Pass, Fail.
markss=int(input("enter your marks in chemistry"))
if markss>=85:
    print("Disctiction")
elif markss>=60:
    print("First Class")
elif markss>=35:
    print("Pass")
else:
    print("Fail")
# Out:
# enter your marks in chemistry 20
# Fail
